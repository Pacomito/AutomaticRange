# %%
from pathlib import Path
import json
import numpy as np
from PIL import Image
import torch
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as T
import random
import sys, os
import importlib
from scipy.ndimage import gaussian_filter
from scipy.ndimage import binary_dilation, label
from scipy.signal import find_peaks
import numpy as np
from tifffile import imread, imwrite
sys.path.append(os.path.abspath(".."))
import data
import models
importlib.reload(data)
from data import RangeAnnotationDataset
importlib.reload(models)
from models import AutomaticRangeNet

# %%
output_base_dir = "/media/localadmin/EGlab20TB-5/TMA_final_run_01/input_processed/"
Path(output_base_dir).mkdir(exist_ok=True)
sample_dir = "/media/localadmin/EGlab20TB-5/TMA_final_run_01/input/"

for sample in Path(sample_dir).glob("*/"):
    print(f"Processing sample: {sample.name}")
    if not sample.is_dir():
        continue

    output_sample_dir = Path(output_base_dir) / sample.name
    output_sample_dir.mkdir(exist_ok=True)

    for img in sample.glob("*.tiff"):
        if "DAPI" in img.name:
            # Copy DAPI files intact
            output_path = output_sample_dir / img.name
            img_data = imread(img)
            preprocessed_data = RangeAnnotationDataset.preprocess_data(img_data, percentile=99.99)  # Assuming preprocess_data is defined elsewhere
            imwrite(output_path, preprocessed_data.astype(np.float16))
        else:
            print(f"Processing {img.name}")
            img_data = imread(img)
            cleaned, mask = RangeAnnotationDataset.remove_bright_aggregates(img_data, threshold_factor=10)
            preprocessed_data = RangeAnnotationDataset.preprocess_data(cleaned, percentile=99.9)  # Assuming preprocess_data is defined elsewhere
            imwrite(output_sample_dir / f"{img.stem}.tiff", preprocessed_data.astype(np.float16))

            #if np.any(mask):
            #    spots_dir = Path(output_base_dir, "spots") / sample.name
            #    spots_dir.mkdir(parents=True, exist_ok=True)
            #    imwrite(spots_dir / f"{img.stem}_mask.tiff", mask.astype(np.uint8) * 255)
# Out:
# Processing sample: AD145_TMA1
# Processing S100A4.tiff
# Processing CD2.tiff
# Artifact detected: Brightest bin value 61990.6523 exceeds threshold 27360.0000
# Detected 6 large & bright enough spots in the image.
# Processing CD8a.tiff
# Artifact detected: Brightest bin value 64255.0195 exceeds threshold 5340.0000
# Detected 19 large & bright enough spots in the image.
# Processing CD79a.tiff
# Artifact detected: Brightest bin value 5024.1191 exceeds threshold 2130.0000
# Detected 4 large & bright enough spots in the image.
# Processing PTPRC.tiff
# Artifact detected: Brightest bin value 63871.0254 exceeds threshold 62360.0000
# No significant artifacts detected after size filtering.
# Processing CXCR3.tiff
# Artifact detected: Brightest bin value 63615.0293 exceeds threshold 14590.0000
# Discarding spot with average intensity 7242.6459 below threshold 14590.0000
# Detected 32 large & bright enough spots in the image.
# Processing IL3RA.tiff
# ...

# %%
# Out:
# Processing sample: spots
# Processing sample: MF018_early_TMA1
# Processing sample: MF003_early_TMA1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1778945/1423850245.py in ?()
#      10     output_sample_dir.mkdir(exist_ok=True)
#      11
#      12     for img in sample.glob("*.tiff"):
#      13         output_path = output_sample_dir / img.name
# ---> 14         img_data = imread(img)
#      15         imwrite(output_sample_dir / f"{img.stem}.tiff", preprocessed_data.astype(np.float16))
#
# ~/anaconda3/envs/napari-env3/lib/python3.10/site-packages/tifffile/tifffile.py in ?(files, aszarr, key, series, level, squeeze, maxworkers, mode, name, offset, size, pattern, axesorder, categories, imread, sort, container, chunkshape, dtype, axestiled, ioworkers, chunkmode, fillvalue, zattrs, multiscales, omexml, out, out_inplace, _multifile, _useframes, **kwargs)
# ...

# %%
spots_dir = Path(output_base_dir, "spots") / sample.name

# %%
spots_dir
# Out:
# PosixPath('/media/localadmin/EGlab20TB-5/TMA_final_run_01/input_processed/spots/AD145_TMA1')

# %%
sample_dir = "/media/localadmin/EGlab20TB-5/TMA_final_run_01/input/ /"
for img in Path(sample_dir).glob("*.tiff"):
    print(f"Processing {img.name}")
    img_data = imread(img)
    cleaned, mask = RangeAnnotationDataset.remove_bright_aggregates(img_data, threshold_factor=2.5)
    imwrite("../data/cleaned_" + img.stem + ".tiff", cleaned.astype(np.float32))
    imwrite("../data/mask_" + img.stem + ".tiff", mask.astype(np.uint8) * 255)  # Save mask as uint8 image
# Out:
# Processing DAPI.tiff
# Processing S100A4.tiff
# Artifact detected: Brightest bin value 61695.0586 exceeds threshold 11657.5000
# Processing CD2.tiff
# Artifact detected: Brightest bin value 63743.0273 exceeds threshold 772.5000
# Processing CD8a.tiff
# Artifact detected: Brightest bin value 63871.0254 exceeds threshold 365.0000
# Processing CD79a.tiff
# Artifact detected: Brightest bin value 3319.6035 exceeds threshold 420.0000
# Processing PTPRC.tiff
# Artifact detected: Brightest bin value 63231.0352 exceeds threshold 4372.5000
# Processing CXCR3.tiff
# Artifact detected: Brightest bin value 64127.0215 exceeds threshold 1977.5000
# Processing IL3RA.tiff
# Artifact detected: Brightest bin value 5126.6016 exceeds threshold 927.5000
# Processing CD3E.tiff
# Artifact detected: Brightest bin value 6704.1367 exceeds threshold 2450.0000
# Processing ACTB.tiff
# Artifact detected: Brightest bin value 6643.4297 exceeds threshold 4740.0000
# Processing ACTG1.tiff
# ...

# %%
    imwrite("../data/cleaned_" + img.stem + ".tiff", cleaned.astype(np.int16))

# %%
smoothed_regions = feather_blend(cleaned, noise_bg, mask, feather_radius=20)

# %%
smoothed_regions
# Out:
# array([[166., 137., 114., ..., 108., 103.,  98.],
#        [147., 139., 126., ..., 137., 120., 116.],
#        [165., 125., 163., ..., 149., 122., 114.],
#        ...,
#        [129.,  88.,  93., ..., 120., 104., 108.],
#        [145.,  87.,  91., ..., 161., 185., 133.],
#        [127., 101., 103., ..., 116., 146., 124.]], dtype=float32)

# %%
cleaned_values = cleaned[spot_mask]
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[114], line 1
# ----> 1 cleaned_values = cleaned[spot_mask]
#
# MemoryError: Unable to allocate 372. GiB for an array with shape (5112, 6254, 6254) and data type uint16

# %%
# Ensure spot_mask has the same shape as cleaned
if spot_mask.shape != cleaned.shape:
    raise ValueError("spot_mask and cleaned must have the same shape.")

# Access only the elements of cleaned where spot_mask is True
cleaned_values = cleaned[spot_mask]
print(cleaned_values)

# %%
large_bg = tiled[:out_size, :out_size]
# Smooth a little for realism
large_bg = gaussian_filter(large_bg, sigma=1.5)

# %%
patch
# Out:
# array([[ 99, 112, 114, ...,  93,  79, 127],
#        [107, 115, 114, ..., 108,  52,  89],
#        [116, 114, 133, ...,  91,  81,  84],
#        ...,
#        [127, 144, 105, ..., 134, 147, 117],
#        [103, 100,  90, ..., 118, 117, 109],
#        [ 89, 101, 139, ..., 171, 140, 132]], dtype=uint16)

# %%
noise
# Out:
# array([[109, 111, 112, ..., 105, 113, 120],
#        [112, 113, 114, ..., 105, 112, 118],
#        [117, 117, 116, ..., 104, 110, 115],
#        ...,
#        [112, 111, 109, ..., 103, 108, 111],
#        [110, 109, 108, ..., 103, 109, 113],
#        [110, 109, 107, ..., 103, 110, 113]], dtype=uint16)

# %%
imwrite("../data/patch.tiff", patch.astype(np.float32))
imwrite("../data/noise_bg.tiff", noise_bg.astype(np.float32))

# %%
x
# Out:
# 2833

# %%
# train.py
import os
import json
import torch
from torch import nn, optim
from torch.utils.data import DataLoader, random_split
from torch.utils.tensorboard import SummaryWriter
from data import RangeAnnotationDataset
from models import AutomaticRangeNet

# Batch
BATCH = "2_annotators_CD4"
# --- Config ---
config = {
    "data": {
        "annotations_dir": "../annotations/" + BATCH + "/",
        "marker_dir": "../data/" + BATCH + "/tiles_marker/",
        "dapi_dir": "../data/" + BATCH + "/tiles_DAPI/"
    },
    "train_params": {
        "batch_size": 10,
        "epochs": 25,
        "learning_rate": 1e-3,  
        "val_split": 0.2,
        "shuffle": True,
        "augment": True
    },
    "log_dir": "logs"
}


# --- Constants ---
RANGE_MIN = 0
RANGE_MAX = 1


# --- Dataset ---
dataset = RangeAnnotationDataset(
    annotations_dir=config["data"]["annotations_dir"],
    tiles_marker_dir=config["data"]["marker_dir"],
    tiles_dapi_dir=config["data"]["dapi_dir"],
    augment=config["train_params"]["augment"]
)

# --- Load model ---
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = AutomaticRangeNet().to(device)  # Move model to GPU
model.load_state_dict(torch.load("../checkpoints/automatic_range.pt", map_location=device))
model.eval()

# --- Predict range ---
input_tensor = torch.from_numpy(np.stack([marker, dapi])[None, :, :, :]).float().to(device)  # Move input to GPU
with torch.no_grad():
    pred_min, pred_max = model(input_tensor).squeeze().tolist()

# %%
# Ensure the model is on the correct device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = AutomaticRangeNet().to(device)  # Move model to GPU
model.load_state_dict(torch.load("../checkpoints/2_annotators_CD4_automatic_range.pt", map_location=device))
model.eval()

# Test predictions for 10 images
N = 10
# Select 10 random indices from the range 1 to 100
random_indices = random.sample(range(1, 101), N)

for idx in random_indices:
    img, target = dataset[idx]
    
    # Move data to GPU
    img = img.unsqueeze(0).to(device)  # Add batch dimension and move to GPU
    target = target.to(device)  # Move target to GPU

    with torch.no_grad():
        pred = model(img)  # Predict range

    # Denormalize predictions and targets
    pred = pred.squeeze().cpu().numpy()  # Move prediction back to CPU and convert to numpy
    target = target.cpu().numpy()  # Move target back to CPU and convert to numpy

    pred_denorm = pred * (RANGE_MAX - RANGE_MIN) + RANGE_MIN
    target_denorm = target * (RANGE_MAX - RANGE_MIN) + RANGE_MIN

    print(f"\nTile {idx}")
    print(f"Predicted range: {pred_denorm}")
    print(f"Actual    range: {target_denorm}")
# Out:
# /tmp/ipykernel_11143/3242907613.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
N = 10
for i in range(N):
    img, target = dataset[i]
    with torch.no_grad():
        pred = model(img.unsqueeze(0))  # add batch dim

    # Denormalize predictions and targets
    pred = pred.squeeze().numpy()
    target = target.numpy()

    pred_denorm = pred * (RANGE_MAX - RANGE_MIN) + RANGE_MIN
    target_denorm = target * (RANGE_MAX - RANGE_MIN) + RANGE_MIN

    print(f"\nTile {i+1}")
    # print(f"Predicted range: {pred}")
    print(f"Predicted range: {pred_denorm}")
    print(f"Actual    range: {target_denorm}")
# Out:
# Loading annotation from ../annotations/2_annotators_CD4/MF157_early_TMA1_x7757_y322_CD4.json
# Base name for tile: MF157_early_TMA1_x7757_y322
# Suffix for tile: CD4
# Found marker image: ../data/2_annotators_CD4/tiles_marker/MF157_early_TMA1_x7757_y322_CD4.tiff
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[28], line 5
#       3 img, target = dataset[i]
#       4 with torch.no_grad():
# ----> 5     pred = model(img.unsqueeze(0))  # add batch dim
#       7 # Denormalize predictions and targets
#       8 pred = pred.squeeze().numpy()
#
# File ~/anaconda3/envs/napari-env3/lib/python3.10/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# ...

# %%
import napari
import numpy as np
from skimage.io import imread
import json
import os
import torch
from models import AutomaticRangeNet

# --- Helper to load normalized image ---
def load_img(path):
    return imread(path).astype(np.float32) / 1.0  # Already normalized to [0, 1]

# --- Load model ---
model = AutomaticRangeNet()
model.load_state_dict(torch.load("../checkpoints/automatic_range.pt", map_location="cpu"))
model.eval()
# Out:
# /tmp/ipykernel_1773276/1121043762.py:15: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
# --- Tiles to test ---
tile_paths = [
    "MF066_late_TMA2_x1558_y2196_CD4",
    "AD088_TMA1_x76_y1877_CD4",
    "MF209_early_TMA2_x3469_y1683_CD4"
]

annotations_dir = "../annotations"
marker_dir = "../data/tiles_marker"
dapi_dir = "../data/tiles_DAPI"

viewer = napari.Viewer()

# %%
for tile_name in tile_paths:
    marker_path = os.path.join(marker_dir, f"{tile_name}.tiff")

    dapi_tile_name = tile_name.replace("CD4", "DAPI")
    dapi_path = os.path.join(dapi_dir, f"{dapi_tile_name}.tiff")
    annotation_path = os.path.join(annotations_dir, f"{tile_name}.json")

    # Load images
    marker = load_img(marker_path)
    dapi = load_img(dapi_path)

    # Load true range
    with open(annotation_path) as f:
        annotation = json.load(f)
    true_min, true_max = annotation["min"], annotation["max"]

    # Predict range
    input_tensor = torch.from_numpy(np.stack([marker, dapi])[None, :, :, :]).float()
    with torch.no_grad():
        pred_min, pred_max = model(input_tensor).squeeze().tolist()

    # Add DAPI
    viewer.add_image(dapi, name=f"{tile_name} - DAPI", colormap='bop blue',contrast_limits=(0, 1))

    # Add marker (true range)
    viewer.add_image(
        marker, 
        name=f"{tile_name} - marker (true)",
        colormap='green',
        contrast_limits=(true_min, true_max),
        blending='additive'
    )

    # Add marker (predicted range)
    viewer.add_image(
        marker, 
        name=f"{tile_name} - marker (pred)",
        colormap='magenta',
        contrast_limits=(pred_min, pred_max),
        blending='additive'
    )

napari.run()

# %%
# Print the max of the modified image
print("Max intensity after modification:", img.max())
# Out:
# Max intensity after modification: 580

# %%
# Save the mask
mask_output_path = "../data/tiles_marker/AD079_TMA1_x3893_y3878_CD4_mask.tiff"
imwrite(mask_output_path, mask.astype(np.uint8) * 255)  # Save as binary mask
# Out:
# Median without bright spots: 0.0028898950004810084

# %%
center = (37, 913)
pointA = (55, 1013)
pointB = (77, 819)
pointC = (127, 920)

avg_distance_to_center = np.mean([
    np.linalg.norm(np.array(center) - np.array(pointA)),
    np.linalg.norm(np.array(center) - np.array(pointB)),
    np.linalg.norm(np.array(center) - np.array(pointC))
])
print("Average distance to center:", avg_distance_to_center)
# Out:
# Average distance to center: 98.01188014956715
